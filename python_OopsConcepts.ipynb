# %% [markdown]
# #Python OOPs
#
#  1. What is Object-Oriented Programming (OOP)?
#
# - OOP is a programming paradigm based on objects that contain data (attributes) and methods (functions).
#
# 2. What is a class in OOP?
#
# - A class is a blueprint that defines the properties and behaviours of objects.
#
# 3. What is an object in OOP?
#
# - An object is an instance of a class that represents a real-world entity.
#
# 4. What is the difference between abstraction and encapsulation?
#
# - Abstraction hides implementation details; encapsulation protects data by restricting access.
#
# 5. What are dunder methods in Python?
#
# - Dunder (double underscore) methods are special methods like __init__, __str__ used to define object behavior.
#
# 6. Explain the concept of inheritance in OOP.
#
# - Inheritance allows a class to acquire properties and methods of another class.
#
# 7. What is polymorphism in OOP?
#
# - Polymorphism allows the same method name to behave differently for different objects.
#
# 8. How is encapsulation achieved in Python?
#
# - By using private variables (_var, __var) and getter/setter methods.
#
# 9. What is a constructor in Python?
#
# - A constructor (__init__) initializes an object when it is created.
#
# 10. What are class and static methods in Python?
#
# - Class methods work with class variables; static methods don’t access class or instance data.
#
# 11. What is method overloading in Python?
#
# - Python supports method overloading using default arguments or *args.
#
# 12. What is method overriding in OOP?
#
# - Method overriding occurs when a child class provides its own implementation of a parent class method.
#
# 13. What is a property decorator in Python?
#
# - @property allows a method to be accessed like an attribute.
#
# 14. Why is polymorphism important in OOP?
#
# - It improves flexibility, code reuse, and scalability.
#
# 15. What is an abstract class in Python?
#
# - An abstract class cannot be instantiated and contains abstract methods, defined using abc module.
#
# 16. What are the advantages of OOP?
#
# - Code reusability, modularity, scalability, and easier maintenance.
#
# 17. What is multiple inheritance in Python?
#
# - A class inheriting from more than one parent class.
#
#
# 18. What is the difference between a class variable and an instance variable?
#
# - Class variables are shared; instance variables are unique to each object.
#
# 19. Explain the purpose of __str__ and __repr__ methods in Python.
#
# - __str__ is for readable output; __repr__ is for developer/debug representation.
#
# 20. What is the significance of the super() function in Python?
#
# - It calls parent class methods without explicitly naming the parent class.
#
# 21. What is the significance of the __del__ method in Python?
#
# - It is a destructor called when an object is deleted.
#
# 22. What is the difference between @staticmethod and @classmethod?
#
# - Static methods don’t use class data; class methods use cls to access class data.
#
# 23. How does polymorphism work in Python with inheritance?
#
# - Child classes override parent methods, allowing dynamic method behavior.
#
# 24. What is method chaining in Python OOP?
#
# - Calling multiple methods in a single line by returning self.
#
# 25. What is the purpose of the __call__ method in Python?
#
# - It allows an object to be called like a function.

# %%
# 1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Testing
animal = Animal()
animal.speak()  # Parent class method

dog = Dog()
dog.speak()     # Overridden method in child class
# Out:
# This animal makes a sound.
# Bark!

# %%
#2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

# Circle class
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Rectangle class
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Testing
circle = Circle(5)
print("Circle area:", round(circle.area(), 2))  # Rounded for clarity

rectangle = Rectangle(4, 6)
print("Rectangle area:", rectangle.area())
# Out:
# Circle area: 78.54
# Rectangle area: 24

# %%
#3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
#and further derive a class ElectricCar that adds a battery attribute.
# Parent class
class Vehicle:
    def __init__(self, vehicle_type):
        self.type = vehicle_type

# Child class
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

# Grandchild class
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery):
        super().__init__(vehicle_type, brand)
        self.battery = battery

    def display_info(self):
        print(f"Type: {self.type}")
        print(f"Brand: {self.brand}")
        print(f"Battery: {self.battery} kWh")

# Testing
ecar = ElectricCar("Car", "Tesla", 100)
ecar.display_info()
# Out:
# Type: Car
# Brand: Tesla
# Battery: 100 kWh

# %%
#4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.
# Base class
class Bird:
    def fly(self):
        print("This bird can fly.")

# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow is flying high!")

# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, they swim instead.")

# Testing
bird = Bird()
bird.fly()

sparrow = Sparrow()
sparrow.fly()

penguin = Penguin()
penguin.fly()
# Out:
# This bird can fly.
# Sparrow is flying high!
# Penguins cannot fly, they swim instead.

# %%
#5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance.
# Class demonstrating encapsulation
class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance  # Private attribute

    # Method to deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited: {amount}")
        else:
            print("Invalid deposit amount")

    # Method to withdraw money
    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrawn: {amount}")
        else:
            print("Insufficient balance or invalid amount")

    # Method to check balance
    def check_balance(self):
        print(f"Current Balance: {self.__balance}")

# Testing
account = BankAccount(1000)
account.deposit(500)
account.withdraw(300)
account.check_balance()
# Out:
# Deposited: 500
# Withdrawn: 300
# Current Balance: 1200

# %%
#6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().
# Base class
class Instrument:
    def play(self):
        print("This instrument is being played.")

# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Guitar is strumming chords.")

# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Piano is playing melodies.")

# Testing runtime polymorphism
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()  # Method call resolved at runtime
# Out:
# Guitar is strumming chords.
# Piano is playing melodies.

# %%
#7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.
# Class demonstrating class and static methods
# Class demonstrating class and static methods
class MathOperations:

    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# Testing
sum_result = MathOperations.add_numbers(10, 5)
diff_result = MathOperations.subtract_numbers(10, 5)

print("Sum:", sum_result)
print("Difference:", diff_result)
# Out:
# Sum: 15
# Difference: 5

# %%
#8. Implement a class Person with a class method to count the total number of persons created.
# Class demonstrating counting instances using a class method
class Person:
    count = 0  # Class variable to keep track of persons

    def __init__(self, name):
        self.name = name
        Person.increment_count()  # Increment count when a new person is created

    # Class method to increment count
    @classmethod
    def increment_count(cls):
        cls.count += 1

    # Class method to get total count
    @classmethod
    def total_persons(cls):
        return cls.count

# Testing
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total Persons Created:", Person.total_persons())
# Out:
# Total Persons Created: 3

# %%
#9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the
#fraction as "numerator/denominator"
# Class representing a fraction
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Overriding __str__ method
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# Testing
f1 = Fraction(3, 4)
f2 = Fraction(7, 8)

print(f1)
print(f2)
# Out:
# 3/4
# 7/8

# %%
#10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
# Class demonstrating operator overloading
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # Overriding __str__ to print vector
    def __str__(self):
        return f"({self.x}, {self.y})"

# Testing
v1 = Vector(2, 3)
v2 = Vector(4, 5)
v3 = v1 + v2  # Uses overloaded + operator

print("v1:", v1)
print("v2:", v2)
print("v1 + v2 =", v3)
# Out:
# v1: (2, 3)
# v2: (4, 5)
# v1 + v2 = (6, 8)

# %%
#11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."
# Class Person
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # Method to greet
    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# Testing
p1 = Person("Alice", 25)
p2 = Person("Bob", 30)

p1.greet()
p2.greet()
# Out:
# Hello, my name is Alice and I am 25 years old.
# Hello, my name is Bob and I am 30 years old.

# %%
#12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades
# Class Student
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # List of grades

    # Method to calculate average grade
    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)

# Testing
s1 = Student("Alice", [85, 90, 78])
s2 = Student("Bob", [70, 75, 80, 85])

print(f"{s1.name}'s average grade: {s1.average_grade():.2f}")
print(f"{s2.name}'s average grade: {s2.average_grade():.2f}")
# Out:
# Alice's average grade: 84.33
# Bob's average grade: 77.50

# %%
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.
# Class Rectangle
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set dimensions
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate area
    def area(self):
        return self.length * self.width

# Testing
rect = Rectangle()
rect.set_dimensions(5, 3)
print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 15

# %%
# 14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    # Method to calculate salary
    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    # Overriding method to add bonus
    def calculate_salary(self):
        return super().calculate_salary() + self.bonus

# Testing
emp = Employee("Alice", 40, 200)
mgr = Manager("Bob", 40, 200, 5000)

print(f"{emp.name}'s Salary: {emp.calculate_salary()}")
print(f"{mgr.name}'s Salary: {mgr.calculate_salary()}")
# Out:
# Alice's Salary: 8000
# Bob's Salary: 13000

# %%
#15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.
# Class Product
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity

# Testing
p1 = Product("Laptop", 50000, 2)
p2 = Product("Mouse", 500, 5)

print(f"Total price of {p1.name}: {p1.total_price()}")
print(f"Total price of {p2.name}: {p2.total_price()}")
# Out:
# Total price of Laptop: 100000
# Total price of Mouse: 2500

# %%
#from abc import ABC, abstractmethod

# Abstract class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

# Derived class 1
class Cow(Animal):
    def sound(self):
        print("Cow says: Moo")

# Derived class 2
class Sheep(Animal):
    def sound(self):
        print("Sheep says: Baa")

# Testing
cow = Cow()
sheep = Sheep()

cow.sound()
sheep.sound()
# Out:
# Cow says: Moo
# Sheep says: Baa

# %%
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.
# Class Book
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to get book information
    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

# Testing
book1 = Book("1984", "George Orwell", 1949)
book2 = Book("To Kill a Mockingbird", "Harper Lee", 1960)

print(book1.get_book_info())
print(book2.get_book_info())
# Out:
# Title: 1984, Author: George Orwell, Year Published: 1949
# Title: To Kill a Mockingbird, Author: Harper Lee, Year Published: 1960

# %%
#18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
#attribute number_of_rooms.
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def show_info(self):
        print(f"Address: {self.address}")
        print(f"Price: {self.price}")

# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def show_info(self):
        super().show_info()
        print(f"Number of Rooms: {self.number_of_rooms}")

# Testing
house = House("123 Main St", 500000)
mansion = Mansion("456 Elite Ave", 2000000, 10)

print("House Info:")
house.show_info()

print("\nMansion Info:")
mansion.show_info()
# Out:
# House Info:
# Address: 123 Main St
# Price: 500000
#
# Mansion Info:
# Address: 456 Elite Ave
# Price: 2000000
# Number of Rooms: 10
